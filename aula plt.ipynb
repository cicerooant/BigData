# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('D:\Aluno\Downloads\Dados-Pesquisa.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_16572\421134498.py:1: SyntaxWarning: invalid escape sequence '\A'
#   dados = pd.read_csv('D:\Aluno\Downloads\Dados-Pesquisa.csv')
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_16572\421134498.py:1: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('D:\Aluno\Downloads\Dados-Pesquisa.csv')

# %%
dados.head()
dados.tail()
dados.shape
dados.head(1-2)
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15614  47.0               0.0             NaN                   NaN
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 15614                NaN                NaN          NaN                 NaN
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                    NaN             NaN  ...               NaN
# 1                    NaN             NaN  ...               NaN
# 2                    NaN             NaN  ...               NaN
# 3                    NaN             NaN  ...               NaN
# 4                    NaN             NaN  ...               NaN
# ...                  ...             ...  ...               ...
# 15614                NaN             NaN  ...               NaN
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 15614                    NaN                NaN              NaN
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                NaN                NaN              NaN
# 1                1.0                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN
# ...              ...                ...              ...
# 15614            NaN                NaN              NaN
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
#
#                                    SchoolDegree              SchoolMajor  \
# 0                some college credit, no degree                      NaN
# 1                some college credit, no degree                      NaN
# 2       high school diploma or equivalent (GED)                      NaN
# 3                             bachelor's degree  Cinematography And Film
# 4                some college credit, no degree                      NaN
# ...                                         ...                      ...
# 15614  trade, technical, or vocational training                      NaN
# 15615                         bachelor's degree                Chemistry
# 15616                         bachelor's degree   Electrical Engineering
# 15617                         bachelor's degree                Chemistry
# 15618        master's degree (non-professional)                     Math
#
#        StudentDebtOwe
# 0             20000.0
# 1                 NaN
# 2                 NaN
# 3              7000.0
# 4                 NaN
# ...               ...
# 15614             NaN
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
#
# [15619 rows x 113 columns]

# %%
dados.tail()
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
# 15619                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
# 15619                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
# 15619                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
# 15619            NaN                NaN              NaN
#
#                              SchoolDegree             SchoolMajor  \
# 15615                   bachelor's degree               Chemistry
# 15616                   bachelor's degree  Electrical Engineering
# 15617                   bachelor's degree               Chemistry
# 15618  master's degree (non-professional)                    Math
# 15619                   bachelor's degree          Graphic Design
#
#        StudentDebtOwe
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
# 15619         40000.0
#
# [5 rows x 113 columns]

# %%
dados.columns.to_list()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
df2 = dados.copy()

# %%
dados.isna().sum()
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
dados.dropna(subset = ['Age'], inplace = True)

# %%
dados.isna().sum().sum()
# Out:
# 994859

# %%
dados.dtypes.value_counts()
# Out:
# float64    85
# object     28
# Name: count, dtype: int64

# %%
dados = dados[['Age','Gender', 'JobPref', 'JobRoleInterest', 'EmploymentField', 'JobRelocateYesNo', 'HoursLearning', 'MoneyForLearning']]
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest                        EmploymentField  \
# 0                            NaN      office and administrative support
# 1        Front-End Web Developer                      food and beverage
# 2                            NaN                                finance
# 3        Front-End Web Developer  arts, entertainment, sports, or media
# 4       Full-Stack Web Developer                              education
# ...                          ...                                    ...
# 15615                        NaN            software development and IT
# 15616    Front-End Web Developer            software development and IT
# 15617                        NaN                                    NaN
# 15618                        NaN                              education
# 15619                        NaN  arts, entertainment, sports, or media
#
#        JobRelocateYesNo  HoursLearning  MoneyForLearning
# 0                   NaN           30.0               0.0
# 1                   1.0           30.0              20.0
# 2                   NaN           20.0              50.0
# 3                   NaN           20.0             100.0
# 4                   1.0           25.0            1300.0
# ...                 ...            ...               ...
# 15615               NaN           40.0               0.0
# 15616               1.0           15.0             100.0
# 15617               NaN           14.0               0.0
# 15618               NaN           10.0              30.0
# 15619               NaN            2.0               0.0
#
# [13613 rows x 8 columns]

# %%
dados = dados.drop_duplicates()

# %%
dados.shape
# Out:
# (12234, 8)

# %%
dados.describe()
# Out:
#                 Age  JobRelocateYesNo  HoursLearning  MoneyForLearning
# count  12234.000000       4669.000000   11807.000000      11643.000000
# mean      29.598823          0.733348      15.713814       1193.690114
# std        9.215518          0.442256      14.548388       4999.765832
# min       10.000000          0.000000       0.000000          0.000000
# 25%       23.000000          0.000000       5.000000          0.000000
# 50%       28.000000          1.000000      10.000000         50.000000
# 75%       34.000000          1.000000      20.000000        400.000000
# max       86.000000          1.000000     100.000000     180000.000000

# %%
dados.loc[dados['Age'] > 30]
# Out:
#         Age  Gender                  JobPref JobRoleInterest  \
# 5      34.0    male  start your own business             NaN
# 7      35.0    male               freelance              NaN
# 8      33.0    male                      NaN             NaN
# 9      33.0    male  start your own business             NaN
# 10     57.0    male               freelance              NaN
# ...     ...     ...                      ...             ...
# 15611  37.0    male  start your own business             NaN
# 15612  45.0  female  start your own business             NaN
# 15614  47.0    male               freelance              NaN
# 15615  39.0    male  start your own business             NaN
# 15617  37.0    male               freelance              NaN
#
#                          EmploymentField  JobRelocateYesNo  HoursLearning  \
# 5                                finance               NaN            5.0
# 7      office and administrative support               NaN            NaN
# 8                   software development               NaN            5.0
# 9                                    NaN               NaN           20.0
# 10                                   NaN               NaN            8.0
# ...                                  ...               ...            ...
# 15611        software development and IT               NaN           40.0
# 15612                                NaN               NaN            2.0
# 15614                            finance               NaN            3.0
# 15615        software development and IT               NaN           40.0
# 15617                                NaN               NaN           14.0
#
#        MoneyForLearning
# 5                   0.0
# 7                   0.0
# 8                3000.0
# 9                  30.0
# 10                400.0
# ...                 ...
# 15611             200.0
# 15612             300.0
# 15614               0.0
# 15615               0.0
# 15617               0.0
#
# [4510 rows x 8 columns]

# %%
dados['Age'].unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
dados.Age.unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
Idades = dados.Age

# %%
Idades = dados.Age

plt.hist(Idades, label="Idades", color='lightseagreen')
plt.title('Distribuição por Idades')
plt.xlabel("Idades")
plt.ylabel("Quantidade")
plt.legend()
plt.grid(True)
plt.show()

# %%
dados.Gender.value_counts()
# Out:
# Gender
# male           9360
# female         2697
# genderqueer      65
# agender          36
# trans            36
# Name: count, dtype: int64

# %%
dados.Gender.value_counts().sum()
# Out:
# 12194

# %%
tipos_de_generos = pd.DataFrame(dados.Gender.value_counts())

# %%
tipos_de_generos.head()
# Out:
#              count
# Gender
# male          9360
# female        2697
# genderqueer     65
# agender         36
# trans           36

# %%
tipos_de_generos.columns.name = 'Tipo'

# %%
tipos_de_generos.head()
# Out:
# Tipo         count
# Gender
# male          9360
# female        2697
# genderqueer     65
# agender         36
# trans           36

# %%
tipos_de_generos.iloc[0]
# Out:
# Tipo
# count    9360
# Name: male, dtype: int64

# %%
feminino = tipos_de_generos.iloc[1]
feminino
# Out:
# Tipo
# count    2697
# Name: female, dtype: int64

# %%
total_genero = dados.Gender.value_counts().sum()
total_genero
# Out:
# 12194

# %%
fem = (feminino / total_genero * 100)
fem
# Out:
# Tipo
# count    22.117435
# Name: female, dtype: float64

# %%
dados.groupby('Gender').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6448, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 dados.groupby('Gender').mean()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
dados.groupby('Gender').median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 dados.groupby.agg('Gender').median()
#
# AttributeError: 'function' object has no attribute 'agg'

# %%
genero = dados.Gender.value_counts()

# %%
plt.pie(genero)
plt.legend(dados.Gender.value_counts().index, bbox_to_anchor=(1,1))
plt.show()
